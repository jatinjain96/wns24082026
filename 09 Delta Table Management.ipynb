# %% [markdown]
# ###Prerequisties

# %% [markdown]
# ###Create catalog and Schema

# %%
# %sql
USE CATALOG wns24082026;
DROP TABLE IF EXISTS quickstart_schema.users

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)
df.write.saveAsTable("quickstart_schema.users", mode="OVERWRITE")

# %% [markdown]
# ###Read Delta Table

# %%
spark.read.table("quickstart_schema.users").limit(4).display()

# %%
spark.read.table("quickstart_schema.users").describe().display()

# %% [markdown]
# ###Schema Enforcement

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
)
df.write.saveAsTable("quickstart_schema.users", mode="APPEND")

# %% [markdown]
# ###Schema Evolution

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_006_new_column_education.csv",
    header=True,
    inferSchema=True,
)
df.write.option("mergeSchema",True).saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
spark.read.table("quickstart_schema.users").describe()

# %% [markdown]
# ###Schema Mismatch - Cannot auto convert INT to DATE

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_011_datatype_mismatch_dob.csv",
    header=True,
    inferSchema=True,
)
df.write.saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
df = spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_011_datatype_mismatch_dob.csv",
    header=True,
    inferSchema=True,
)
df.write.option("mergeSchema",True).saveAsTable("quickstart_schema.users", mode="APPEND")

# %% [markdown]
# ###Schema with less columns and different column names

# %%
spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_013_less_columns_with_different_column_names.csv",
    header=True,
    inferSchema=True,
).write.option("mergeSchema",True).saveAsTable("quickstart_schema.users", mode="APPEND")

# %%
from pyspark.sql.functions import *
spark.read.table("quickstart_schema.users").filter(col('id').between(6001,6005)).limit(5).display()

# %%
from pyspark.sql.functions import *

spark.read.csv(
    path="/Volumes/wns24082026/quickstart_schema/sandbox/datasets/user_dataset/users_014_less_columns_with_different_column_names.csv",
    header=True,
    inferSchema=True,).select(
    col("user_id").alias("id"),
    col("full_name").alias("name"),
).write.saveAsTable(
    "quickstart_schema.users", mode="APPEND"
)
